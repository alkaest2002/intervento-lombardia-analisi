# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.DataFrame(data=[
    ["25/01/2021","Cluster DTD Milano Linate",8],
    ["25/01/2021","DTD Caponago",8],
    ["26/01/2021","Cluster DTD Milano Linate",8],
    ["26/01/2021","DTD Meda",8],
    ["27/01/2021","DTD Pavia",8],
    ["28/01/2021","Cluster DTD Milano Linate",8],
    ["29/01/2021","Cluster DTD Milano Linate",8],
    ["29/01/2021","DTD Lecco",8],
    ["01/02/2021","Cluster DTD Milano Linate",8],
    ["02/02/2021","DTD Voghera",8],
    ["03/02/2021","DTD Vigevano",8],
    ["04/02/2021","Cluster DTD Milano Linate",8],
], columns=["Data intervento","Sede intervento","Operatori intervistati"])

# %%
df.to_latex(
    "../latex/tables/tab1.tex", 
    column_format="lll",
    escape=False,
    index=False
)

# %%
df
# Out:
#    Data intervento            Sede intervento  Operatori intervistati
# 0       25/01/2021  Cluster DTD Milano Linate                       8
# 1       25/01/2021               DTD Caponago                       8
# 2       26/01/2021  Cluster DTD Milano Linate                       8
# 3       26/01/2021                   DTD Meda                       8
# 4       27/01/2021                  DTD Pavia                       8
# 5       28/01/2021  Cluster DTD Milano Linate                       8
# 6       29/01/2021  Cluster DTD Milano Linate                       8
# 7       29/01/2021                  DTD Lecco                       8
# 8       01/02/2021  Cluster DTD Milano Linate                       8
# 9       02/02/2021                DTD Voghera                       8
# 10      03/02/2021               DTD Vigevano                       8
# 11      04/02/2021  Cluster DTD Milano Linate                       8
